# %%
# Package dependences
import numpy as np
import pandas as pd
import torch
import os
os.environ["WANDB_MODE"] = "disabled"     # W&B no-op :contentReference[oaicite:2]{index=2}
os.environ["WANDB_DISABLED"] = "true"     # commonly honored by integrations :contentReference[oaicite:3]{index=3}
os.environ["WANDB_SILENT"] = "true"

# %%
import grelu.resources
model = grelu.resources.load_model(
    project="borzoi",
    model_name="human_rep0",
)
# Out:
# wandb: WARNING The anonymous parameter to wandb.login() has no effect and will be removed in future versions.

# %%
for key in model.data_params['train'].keys():
    if key !="intervals":
        print(key, model.data_params['train'][key])
# Out:
# seq_len 524288
# label_len 196608
# genome hg38
# bin_size 32

# %%
tasks = pd.DataFrame(model.data_params["tasks"])

task_filter_mask = (
    (tasks["assay"].astype(str).str.lower() == "rna")
    & (tasks["description"].astype(str).str.contains("lung", case=False, na=False))
    & (tasks["name"].astype(str).str.contains("gtex", case=False, na=False))
)

on_tasks = tasks.loc[task_filter_mask]
on_task_idx = on_tasks.index.to_list()
on_tasks.head()
# Out:
#                             name  \
# 7566  GTEX-1399S-1726-SM-5L3DI.1
# 7567  GTEX-14AS3-0926-SM-5TDD6.1
# 7568  GTEX-14JG1-0926-SM-5YY8W.1
#
#                                                    file  clip  clip_soft  \
# 7566  /home/drk/tillage/datasets/human/rna/recount3/...   768        384
# 7567  /home/drk/tillage/datasets/human/rna/recount3/...   768        384
# 7568  /home/drk/tillage/datasets/human/rna/recount3/...   768        384
#
#       scale  sum_stat  strand_pair description assay sample
# 7566   0.01  sum_sqrt         7566    RNA:lung   RNA   lung
# 7567   0.01  sum_sqrt         7567    RNA:lung   RNA   lung
# 7568   0.01  sum_sqrt         7568    RNA:lung   RNA   lung
